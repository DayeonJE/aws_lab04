# %% [markdown]
# ### Titanic 생존자 데이터셋 분석

# %%
import pandas as pd
import numpy as np
import seaborn as sb

# https://www.kaggle.com/c/titanic

titanic = sb.load_dataset('titanic')
print(type(titanic))  # DataFrame
titanic
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic['survived'].sum()  # 생존자   342 / 891
# Out:
# 342

# %%
titanic['survived'].mean()
# Out:
# 0.3838383838383838

# %%
# 성별 평균 생존율
titanic.pivot_table('survived','sex',aggfunc='mean')

# titanic.pivot_table(values='survived',index='sex',aggfunc='mean')

# DataFrame.pivot_table(
#     values=None,
#     index=None,
#     columns=None,
#     aggfunc='mean',
#     fill_value=None,
#     margins=False,
#     dropna=True,
#     margins_name='All',
#     observed=False,
# )
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %%
#  'pclass' 별 평균 생존율
titanic.pivot_table('survived','pclass',aggfunc='mean')
# Out:
#         survived
# pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
#  'embark_town' 별 평균 생존율
titanic.pivot_table('survived','embark_town',aggfunc='mean')
# Out:
#              survived
# embark_town
# Cherbourg    0.553571
# Queenstown   0.389610
# Southampton  0.336957

# %%
# 'class','sibsp' 를 MultiIndex로 group화 하고 컬럼을 'sex'로 하는 생존율(평균)
titanic.pivot_table('survived',index=['class','sibsp'],columns='sex',
                   aggfunc='mean')
# Out:
# sex             female      male
# class  sibsp
# First  0      0.979592  0.329545
#        1      0.950000  0.483871
#        2      1.000000  0.500000
#        3      1.000000  0.000000
# Second 0      0.931818  0.118421
#        1      0.892857  0.259259
#        2      1.000000  0.200000
#        3      1.000000       NaN
# Third  0      0.592593  0.129630
#        1      0.447368  0.222222
#        2      0.571429  0.125000
#        3      0.125000  0.000000
#        4      0.333333  0.083333
#        5      0.000000  0.000000
#        8      0.000000  0.000000

# %%
# 'age'로 등급 별 평균 생존율
titanic.pivot_table('survived','age',aggfunc='mean')  # 너무 많은 등급으로 출력
titanic['age'].min()   # 0.42
titanic['age'].max()   # 80
titanic['age'].mean()  # 29.69

# 'age'를 5단계로 출력
pd.qcut(titanic.age,5) # titanic.age 는 titanic['age']와 동일

# '(': parentheses is exclusive. 불포함, 초과, '>'
# '[': square bracket is inclusive; 포함, 이하, '<='
# [(0.419, 19.0] < (19.0, 25.0] < (25.0, 31.8] < (31.8, 41.0] < (41.0, 80.0]]
#   'child'         'young'         'middle'       'old'          'very old'
# Out:
# 0       (19.0, 25.0]
# 1       (31.8, 41.0]
# 2       (25.0, 31.8]
# 3       (31.8, 41.0]
# 4       (31.8, 41.0]
#            ...
# 886     (25.0, 31.8]
# 887    (0.419, 19.0]
# 888              NaN
# 889     (25.0, 31.8]
# 890     (31.8, 41.0]
# Name: age, Length: 891, dtype: category
# Categories (5, interval[float64, right]): [(0.419, 19.0] < (19.0, 25.0] < (25.0, 31.8] < (31.8, 41.0] < (41.0, 80.0]]

# %%
titanic['age_class'] = pd.qcut(titanic.age,5,
                    labels=['child','young','middle','old','very old'])
titanic['age2'] = titanic['age']
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone age_class  age2
# 0      man        True  NaN  Southampton    no  False     young  22.0
# 1    woman       False    C    Cherbourg   yes  False       old  38.0
# 2    woman       False  NaN  Southampton   yes   True    middle  26.0
# 3    woman       False    C  Southampton   yes  False       old  35.0
# 4      man        True  NaN  Southampton    no   True       old  35.0
# ..     ...         ...  ...          ...   ...    ...       ...   ...
# 886    man        True  NaN  Southampton    no   True    middle  27.0
# 887  woman       False    B  Southampton   yes   True     child  19.0
# 888  woman       False  NaN  Southampton    no  False       NaN   NaN
# 889    man        True    C    Cherbourg   yes   True    middle  26.0
# 890    man        True  NaN   Queenstown    no   True       old  32.0
#
# [891 rows x 17 columns]

# %%
# 'age_class', 5단계 연령 등급별 생존율
titanic.pivot_table('survived','age_class',aggfunc='mean')
# Out:
#            survived
# age_class
# child      0.481707
# young      0.328467
# middle     0.393701
# old        0.437500
# very old   0.373239

# %%
# 'sex','age_class' 를 MultiIndex로 한 평균 생존율
titanic.pivot_table('survived',index = ['sex','age_class'],aggfunc='mean')
# Out:
#                   survived
# sex    age_class
# female child      0.706667
#        young      0.723404
#        middle     0.727273
#        old        0.843137
#        very old   0.795455
# male   child      0.292135
#        young      0.122222
#        middle     0.216867
#        old        0.215054
#        very old   0.183673

# %%
# 분포의 갯수
titanic['age_class'].value_counts()
# Out:
# child       164
# old         144
# very old    142
# young       137
# middle      127
# Name: age_class, dtype: int64

# %%
titanic['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
# Series 객체의 quantile()함수: 데이터의 백분위수
titanic['age'].quantile([.0,.2,.4,.6,.8,1.0])
# [(0.419, 19.0] < (19.0, 25.0] < (25.0, 31.8] < (31.8, 41.0] < (41.0, 80.0]]
#   'child'         'young'         'middle'       'old'          'very old'
# Out:
# 0.0     0.42
# 0.2    19.00
# 0.4    25.00
# 0.6    31.80
# 0.8    41.00
# 1.0    80.00
# Name: age, dtype: float64

# %%
# 사분위수 시각화 : box plot (상자그림)
titanic['age'].plot.box()
titanic['age'].median()
# Out:
# 28.0

# %%
# qcut()을 사용하여 fare 를 3단계로 분류된 'fare_class'컬럼을 추가
# label : 'First' ,'Second', 'Third'
# 'class'를 복사하여 새로운 컬럼 'class2'로 추가하고 결과를 비교
# 'fare_class' , 3단계 요금 등급별 생존율을 구하기
titanic['fare_class'] = pd.qcut(titanic.fare,3,
                         labels=['Third','Second','First'])
titanic['class2'] = titanic['class']
titanic
# pd.qcut(titanic.fare,3)
# [(-0.001, 8.662] < (8.662, 26.0] < (26.0, 512.329]]
#       'Third'         'Second'         'First'
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone age_class  age2  \
# 0      man        True  NaN  Southampton    no  False     young  22.0
# 1    woman       False    C    Cherbourg   yes  False       old  38.0
# 2    woman       False  NaN  Southampton   yes   True    middle  26.0
# 3    woman       False    C  Southampton   yes  False       old  35.0
# 4      man        True  NaN  Southampton    no   True       old  35.0
# ..     ...         ...  ...          ...   ...    ...       ...   ...
# 886    man        True  NaN  Southampton    no   True    middle  27.0
# 887  woman       False    B  Southampton   yes   True     child  19.0
# 888  woman       False  NaN  Southampton    no  False       NaN   NaN
# 889    man        True    C    Cherbourg   yes   True    middle  26.0
# 890    man        True  NaN   Queenstown    no   True       old  32.0
#
#     fare_class  class2
# 0        Third   Third
# 1        First   First
# 2        Third   Third
# 3        First   First
# 4        Third   Third
# ..         ...     ...
# 886     Second  Second
# 887      First   First
# 888     Second   Third
# 889      First   First
# 890      Third   Third
#
# [891 rows x 19 columns]

# %%
# 'fare_class', 3단계 요금 등급별 생존율
titanic.pivot_table('survived','fare_class',aggfunc='mean')
# Out:
#             survived
# fare_class
# Third       0.198052
# Second      0.402778
# First       0.559322

# %%
# 분포의 갯수
titanic['fare_class'].value_counts()
# Out:
# Third     308
# First     295
# Second    288
# Name: fare_class, dtype: int64

# %%
# 생존한 사람중에서 'fare_class'가 'third'인 사람이 몇명인지 구하기  : 61명
sv_df = titanic[titanic['survived'] == 1]  # 342명
sv_df['fare_class'].value_counts()         # 61명
# Out:
# First     165
# Second    116
# Third      61
# Name: fare_class, dtype: int64

# %%
# 컬럼을 중간에 삽입하는 방법 : DataFrame.insert(컬럼번호,컬럼이름,추가될 컬럼데이터)
# titanic['hello'] = np.arange(891)  # 마지막 위치에 추가
df = titanic.copy()   # copy 는 원본과 메모리를 공유하지 않음

df.insert(4,'age_class_insert',df['age_class'])
df
# Out:
#      survived  pclass     sex   age age_class_insert  sibsp  parch     fare  \
# 0           0       3    male  22.0            young      1      0   7.2500
# 1           1       1  female  38.0              old      1      0  71.2833
# 2           1       3  female  26.0           middle      0      0   7.9250
# 3           1       1  female  35.0              old      1      0  53.1000
# 4           0       3    male  35.0              old      0      0   8.0500
# ..        ...     ...     ...   ...              ...    ...    ...      ...
# 886         0       2    male  27.0           middle      0      0  13.0000
# 887         1       1  female  19.0            child      0      0  30.0000
# 888         0       3  female   NaN              NaN      1      2  23.4500
# 889         1       1    male  26.0           middle      0      0  30.0000
# 890         0       3    male  32.0              old      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone  \
# 0          S   Third    man        True  NaN  Southampton    no  False
# 1          C   First  woman       False    C    Cherbourg   yes  False
# 2          S   Third  woman       False  NaN  Southampton   yes   True
# 3          S   First  woman       False    C  Southampton   yes  False
# 4          S   Third    man        True  NaN  Southampton    no   True
# ..       ...     ...    ...         ...  ...          ...   ...    ...
# 886        S  Second    man        True  NaN  Southampton    no   True
# 887        S   First  woman       False    B  Southampton   yes   True
# 888        S   Third  woman       False  NaN  Southampton    no  False
# 889        C   First    man        True    C    Cherbourg   yes   True
# 890        Q   Third    man        True  NaN   Queenstown    no   True
#
#     age_class  age2 fare_class  class2
# 0       young  22.0      Third   Third
# 1         old  38.0      First   First
# 2      middle  26.0      Third   Third
# 3         old  35.0      First   First
# 4         old  35.0      Third   Third
# ..        ...   ...        ...     ...
# 886    middle  27.0     Second  Second
# 887     child  19.0      First   First
# 888       NaN   NaN     Second   Third
# 889    middle  26.0      First   First
# 890       old  32.0      Third   Third
#
# [891 rows x 20 columns]

# %%
# 상관 관계(Correlation): 피쳐(X값,독립변수),Y값(종속변수,레이블,답)들과의 영향을 주는 정도
titanic.corr() # 상관 계수 : (-1 ~ 1) , 0 이 가장 작은값, 0.5이상이면 상관관계가 크다
# Out:
# C:\Users\storm\AppData\Local\Temp\ipykernel_11884\299550916.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   titanic.corr() # 상관 계수 : (-1 ~ 1) , 0 이 가장 작은값, 0.5이상이면 상관관계가 크다
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
# age2       -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
#
#             adult_male     alone      age2
# survived     -0.557080 -0.203367 -0.077221
# pclass        0.094035  0.135207 -0.369226
# age           0.280328  0.198270  1.000000
# sibsp        -0.253586 -0.584471 -0.308247
# parch        -0.349943 -0.583398 -0.189119
# fare         -0.182024 -0.271832  0.096067
# adult_male    1.000000  0.404744  0.280328
# alone         0.404744  1.000000  0.198270
# age2          0.280328  0.198270  1.000000

# %% [markdown]
# ### 날짜 다루기 : pd.to_datetime(['2023-04-17'])

# %%
# POSIX 시간 표기법 : 1970년 1월 1일(1677~2262)
pd.date_range('9/22/1677',periods=4,freq='D')    # OK!!, 1677-09-21 00:00:00

# pd.date_range('9/21/1677',periods=4,freq='D')  # OutOfBoundsDatetime ,Error!!
# Out:
# DatetimeIndex(['1677-09-22', '1677-09-23', '1677-09-24', '1677-09-25'], dtype='datetime64[ns]', freq='D')

# %%
date1 = '2023-04-17'    # '-', '/', ' ', '.' , ',' , ':'
date2 = '2023/04/18'
type(date1)             # str
# date2 - date1         # TypeError

d1 = pd.to_datetime([date1])
d2 = pd.to_datetime([date2])
print(d1)        # DatetimeIndex
print(d2 - d1)   # TimedeltaIndex 객체, 날짜(day) 단위로 연산이 가능
# Out:
# DatetimeIndex(['2023-04-17'], dtype='datetime64[ns]', freq=None)
# TimedeltaIndex(['1 days'], dtype='timedelta64[ns]', freq=None)

# %%
import time
start = time.time()
for k in range(10000000):
    k = k  + 1
end = time.time()
print(end-start)
# Out:
# 2.181989908218384

# %% [markdown]
# ### 엑셀 파일 읽고 쓰기
# * pd.read_excel()
# * df.to_excel()

# %%
# 읽기
df = pd.read_excel('excel_exam.xlsx',index_col='id')
type(df)     # DataFrame

df2 = df.drop(['class'],axis=1)         # 열을 삭제
df2

df['total'] = df2.sum(axis=1)           # 열방향, 각 행의 합을 구함
df['mean'] = round(df2.mean(axis=1),2)  # 소숫점 두자리로 반올림
df
# Out:
#     class  math  english  science  total   mean
# id
# 1       1    50       98       50    198  66.00
# 2       1    60       97       60    217  72.33
# 3       1    45       86       78    209  69.67
# 4       1    30       98       58    186  62.00
# 5       2    25       80       65    170  56.67
# 6       2    50       89       98    237  79.00
# 7       2    80       90       45    215  71.67
# 8       2    90       78       25    193  64.33
# 9       3    20       98       15    133  44.33
# 10      3    50       98       45    193  64.33
# 11      3    65       65       65    195  65.00
# 12      3    45       85       32    162  54.00
# 13      4    46       98       65    209  69.67
# 14      4    48       87       12    147  49.00
# 15      4    75       56       78    209  69.67
# 16      4    58       98       65    221  73.67
# 17      5    65       68       98    231  77.00
# 18      5    80       78       90    248  82.67
# 19      5    89       68       87    244  81.33
# 20      5    78       83       58    219  73.00

# %%
# 쓰기
df.to_excel('new_exam.xlsx',index=True)

# %%
# 데이터 프레임 정렬, 새로운 컬럼 추가
df = pd.read_excel('excel_exam.xlsx',index_col='id')
df['총점'] = df['math'] + df['english'] + df['science']
df['평균'] = round((df['math'] + df['english'] + df['science'])/3,2)

# 평균이 75점 보다 큰 행을 추출
df_75 = df[df['평균'] > 75]
df_75   # 4개행을 추출

df = df.sort_values(by='평균',ascending=True)  # 오름차순
df = df.sort_values(by='평균',ascending=False) # 내림차순
df
# Out:
#     class  math  english  science   총점     평균
# id
# 18      5    80       78       90  248  82.67
# 19      5    89       68       87  244  81.33
# 6       2    50       89       98  237  79.00
# 17      5    65       68       98  231  77.00
# 16      4    58       98       65  221  73.67
# 20      5    78       83       58  219  73.00
# 2       1    60       97       60  217  72.33
# 7       2    80       90       45  215  71.67
# 15      4    75       56       78  209  69.67
# 13      4    46       98       65  209  69.67
# 3       1    45       86       78  209  69.67
# 1       1    50       98       50  198  66.00
# 11      3    65       65       65  195  65.00
# 8       2    90       78       25  193  64.33
# 10      3    50       98       45  193  64.33
# 4       1    30       98       58  186  62.00
# 5       2    25       80       65  170  56.67
# 12      3    45       85       32  162  54.00
# 14      4    48       87       12  147  49.00
# 9       3    20       98       15  133  44.33

# %%
# 'Pass' or 'Fail' 로 분류하기
df['합격'] = '0'
df2 = df[df['평균'] >= 75]  # 합격자
df3 = df[df['평균'] < 75]   # 불합격자

# df2['합격'] = 'Pass'  # SettingWithCopyWarning
df2.loc[:,'합격'] = 'Pass'

df3.loc[:,'합격'] = 'Fail'
df3

result = df2.append(df3)
result
# Out:
# C:\Users\storm\AppData\Local\Temp\ipykernel_11884\3972393329.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[:,'합격'] = 'Pass'
# C:\Users\storm\AppData\Local\Temp\ipykernel_11884\3972393329.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.loc[:,'합격'] = 'Fail'
# C:\Users\storm\AppData\Local\Temp\ipykernel_11884\3972393329.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = df2.append(df3)
#     class  math  english  science   총점     평균    합격
# id
# 18      5    80       78       90  248  82.67  Pass
# 19      5    89       68       87  244  81.33  Pass
# 6       2    50       89       98  237  79.00  Pass
# 17      5    65       68       98  231  77.00  Pass
# 16      4    58       98       65  221  73.67  Fail
# 20      5    78       83       58  219  73.00  Fail
# 2       1    60       97       60  217  72.33  Fail
# 7       2    80       90       45  215  71.67  Fail
# 15      4    75       56       78  209  69.67  Fail
# 13      4    46       98       65  209  69.67  Fail
# 3       1    45       86       78  209  69.67  Fail
# 1       1    50       98       50  198  66.00  Fail
# 11      3    65       65       65  195  65.00  Fail
# 8       2    90       78       25  193  64.33  Fail
# 10      3    50       98       45  193  64.33  Fail
# 4       1    30       98       58  186  62.00  Fail
# 5       2    25       80       65  170  56.67  Fail
# 12      3    45       85       32  162  54.00  Fail
# 14      4    48       87       12  147  49.00  Fail
# 9       3    20       98       15  133  44.33  Fail

# %%
df = pd.DataFrame({'a': [1,2,3],
                   'b': ['one','two','three']})
print(df)
df1 = df            # 원본과 메모리 공유
df2 = df.copy()     # copy본, 원본과 별도의 메모리 사용
df3 = df['a']       # copy본, 원본과 별도의 메모리 사용
df4 = df.loc[:,'a'] # copy본, 원본과 별도의 메모리 사용
np.shares_memory(df,df4) # False
# Out:
#    a      b
# 0  1    one
# 1  2    two
# 2  3  three
# False

# %%
# chained assignment : copy본이 만들어 지면서 동시에 인덱싱으로 쓰기 시도시 발생
# SettingWithCopyWarning: get() --> set()
df = pd.DataFrame({'a': [1,2,3],
                   'b': ['one','two','three']})
print(df)

# SettingWithCopyWarning 메세지 출력 옵션 설정
pd.set_option('mode.chained_assignment','warn')  # SettingWithCopyWarning
# pd.set_option('mode.chained_assignment','raise') # SettingWithCopyError,오류처리
# pd.set_option('mode.chained_assignment',None)    # 경고 메세지 출력을 끔

# df['a'][0] = 40    # SettingWithCopyWarning, get()-->set(),사본 생성, 요소변경(원본 or 사본)
df.loc[0,'a'] = 50   # set() , 사본이 생성되지 않는다, 원본이 변경
df
# Out:
#    a      b
# 0  1    one
# 1  2    two
# 2  3  three
#     a      b
# 0  50    one
# 1   2    two
# 2   3  three
